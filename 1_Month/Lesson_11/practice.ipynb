# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
from huggingface_hub import hf_hub_download

# %%
tokenizer = AutoTokenizer.from_pretrained("HuggingFaceTB/SmolLM2-135M")
model = AutoModelForCausalLM.from_pretrained("HuggingFaceTB/SmolLM2-135M")
# Out:
# ...
# model.safetensors: reconstructing file:   0%|          |  0.00B /  269MB
# model.safetensors: downloading bytes:           |  0.00B
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\huggingface_hub\file_download.py:141: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\user\.cache\huggingface\hub\models--HuggingFaceTB--SmolLM2-135M. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# ...

# %%
# Download tokenizer files directly
files = [
    "tokenizer.json",
    "tokenizer_config.json",
    "vocab.json",
    "merges.txt"
]

for file in files:

    path = hf_hub_download(

        repo_id="HuggingFaceTB/SmolLM2-135M",

        filename=file,

        local_dir="./smollm2-135m"

    )

    print(path)
# Out:
# C:\LLM_lesson\1\Lesson_11\smollm2-135m\tokenizer.json
# C:\LLM_lesson\1\Lesson_11\smollm2-135m\tokenizer_config.json
# C:\LLM_lesson\1\Lesson_11\smollm2-135m\vocab.json
# C:\LLM_lesson\1\Lesson_11\smollm2-135m\merges.txt

# %%
print(model.config.num_attention_heads)
# Out:
# 9

# %%
model.model.layers[0].self_attn
# Out:
# LlamaAttention(
#   (q_proj): Linear(in_features=576, out_features=576, bias=False)
#   (k_proj): Linear(in_features=576, out_features=192, bias=False)
#   (v_proj): Linear(in_features=576, out_features=192, bias=False)
#   (o_proj): Linear(in_features=576, out_features=576, bias=False)
# )

# %%
model.model.layers[1].self_attn
# Out:
# LlamaAttention(
#   (q_proj): Linear(in_features=576, out_features=576, bias=False)
#   (k_proj): Linear(in_features=576, out_features=192, bias=False)
#   (v_proj): Linear(in_features=576, out_features=192, bias=False)
#   (o_proj): Linear(in_features=576, out_features=576, bias=False)
# )

# %%
model.model.layers[-2].self_attn
# Out:
# LlamaAttention(
#   (q_proj): Linear(in_features=576, out_features=576, bias=False)
#   (k_proj): Linear(in_features=576, out_features=192, bias=False)
#   (v_proj): Linear(in_features=576, out_features=192, bias=False)
#   (o_proj): Linear(in_features=576, out_features=576, bias=False)
# )

# %%
model.model.layers[12].self_attn
# Out:
# LlamaAttention(
#   (q_proj): Linear(in_features=576, out_features=576, bias=False)
#   (k_proj): Linear(in_features=576, out_features=192, bias=False)
#   (v_proj): Linear(in_features=576, out_features=192, bias=False)
#   (o_proj): Linear(in_features=576, out_features=576, bias=False)
# )

# %%
# from transformers import AutoModel

# models = [
#     "gpt2",
#     "HuggingFaceTB/SmolLM2-135M",
#     "mistralai/Mistral-7B-v0.1"
# ]

# for name in models:
#     model = AutoModel.from_pretrained(name)

#     print("=" * 50)
#     print(name)
#     print(model.config)

# %%
#MQA
from transformers import AutoConfig, AutoModel

config = AutoConfig.from_pretrained("tiiuae/falcon-7b")
config.num_key_value_heads = 1

model = AutoModel.from_config(config)

print("=== FALCON MULTI-QUERY ATTENTION (MQA) ===")
print(model.h[0].self_attention)
# Out:
# config.json:   0%|          | 0.00/1.05k [00:00<?, ?B/s]
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\huggingface_hub\file_download.py:141: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\user\.cache\huggingface\hub\models--tiiuae--falcon-7b. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# ...
